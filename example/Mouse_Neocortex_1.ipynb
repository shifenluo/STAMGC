# %% [markdown]
# Mouse_Neocortex

# %%
import random
import numpy as np
import scanpy as sc
import torch
import argparse
import yaml
from yaml import SafeLoader
from package.data_processing import LoadAdata
from package.model import STAMGC
import warnings


warnings.filterwarnings('ignore')
import os
os.chdir('/root/autodl-tmp/zhangzhuoyue/code/第一个工作3.0')

# %%
file_fold='/root/autodl-tmp/zhangzhuoyue/data'

args = argparse.Namespace(
    dataset='Mouse_Neocortex',
    slice='Mouse_Neocortex_data',
    parameter='Slide_seqV2',
    batch_size=1,
    platform='Slide_seqV2',
    spot_size=20,
    config='./train_config.yaml',
    label=True,
)
config = yaml.load(open(args.config), Loader=SafeLoader)[str(args.parameter)]

slice_path = os.path.join(file_fold, args.platform, args.dataset, args.slice)

torch.manual_seed(config['seed'])
np.random.seed(config['seed'])
if torch.cuda.is_available():
    torch.cuda.manual_seed(config['seed'])
    torch.cuda.manual_seed_all(config['seed'])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
random.seed(12345)
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8' 
torch.use_deterministic_algorithms(True)

# %%
from package.utils import create_dir
save_path='./results/'+args.dataset+'/'+args.slice
create_dir(save_path)
# Out:
# './results/Mouse_Neocortex/Mouse_Neocortex_data'

# %%
file_path=os.path.join(file_fold, args.platform, args.dataset, args.slice)+'/used_barcode.npy'
if os.path.exists(file_path):
    # 情况1: 文件存在，直接加载
    print(f"文件 '{file_path}' 已存在，正在加载...")
    used_barcode = np.load(file_path)
else:
    # 情况2: 文件不存在，生成并保存
    print(f"文件 '{file_path}' 不存在，正在生成并保存...")
    used_barcode = np.random.randint(0, 2, size=41786).astype(bool)
    np.save(file_path, used_barcode)
    print(f"数组已保存到: {file_path}")
# Out:
# 文件 '/root/autodl-tmp/zhangzhuoyue/data/Slide_seqV2/Mouse_Neocortex/Mouse_Neocortex_data/used_barcode.npy' 已存在，正在加载...

# %%
adata = LoadAdata(path=slice_path,dataset=args.dataset,slice=args.slice,config=config,args=args,used_barcode=True).run()
print(adata)
# Out:
# Load data!
# Preprocess!
# WARNING: adata.X seems to be already log-transformed.
# Generate gene expression!
# Load label!
# Gaussian smooth data!
# Construct adjacency matrix!
# adata load done!
# AnnData object with n_obs × n_vars = 20674 × 1933
#     obs: 'barcode', 'x', 'y', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_MT', 'log1p_total_counts_MT', 'pct_counts_MT', 'n_counts', 'leiden', 'cluster', 'ground_truth'
#     var: 'MT', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'dispersions', 'dispersions_norm', 'n_counts', 'mean', 'std'
#     uns: 'cluster_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'moranI', 'neighbors', 'pca', 'spatial_neighbors', 'umap', 'smooth_r'
#     obsm: 'X_pca', 'X_umap', 'deconvolution_results', 'spatial', 'gene_feat', 'smooth_gene', 'graph_neigh_coor', 'graph_neigh', 'negative_mask'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances', 'spatial_connectivities', 'spatial_distances'

# %%
data=sc.read_h5ad(slice_path+'.h5ad')
print(data)
# Out:
# AnnData object with n_obs × n_vars = 41786 × 4000
#     obs: 'barcode', 'x', 'y', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_MT', 'log1p_total_counts_MT', 'pct_counts_MT', 'n_counts', 'leiden', 'cluster'
#     var: 'MT', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'dispersions', 'dispersions_norm'
#     uns: 'cluster_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'moranI', 'neighbors', 'pca', 'spatial_neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'deconvolution_results', 'spatial'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances', 'spatial_connectivities', 'spatial_distances'

# %%
adata=sc.read_h5ad('./results/'+args.dataset+'/'+args.slice+'/data_processing.h5ad')
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 20674 × 1933
#     obs: 'barcode', 'x', 'y', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_MT', 'log1p_total_counts_MT', 'pct_counts_MT', 'n_counts', 'leiden', 'cluster', 'ground_truth'
#     var: 'MT', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'dispersions', 'dispersions_norm', 'n_counts', 'mean', 'std'
#     uns: 'cluster_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'moranI', 'neighbors', 'pca', 'smooth_r', 'spatial_neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'deconvolution_results', 'gene_feat', 'graph_neigh', 'graph_neigh_coor', 'negative_mask', 'smooth_gene', 'spatial'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances', 'spatial_connectivities', 'spatial_distances'

# %%
# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = (10, 5)
adata=STAMGC(adata,config,args,load=False).run()
# Out:
# === Generate pseudo labels! ===
# === train ===
# epoch: 0  total_loss: 6.837850570678711  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 1  total_loss: 6.797198295593262  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 2  total_loss: 6.7662482261657715  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 3  total_loss: 6.736515998840332  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 4  total_loss: 6.701156139373779  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 5  total_loss: 6.658824443817139  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 6  total_loss: 6.6178059577941895  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 7  total_loss: 6.578173637390137  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 8  total_loss: 6.534895896911621  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 9  total_loss: 6.492095947265625  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 10  total_loss: 6.453422546386719  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 11  total_loss: 6.418314456939697  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 12  total_loss: 6.386560440063477  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 13  total_loss: 6.360941410064697  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 14  total_loss: 6.340104103088379  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 15  total_loss: 6.322201728820801  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 16  total_loss: 6.307689666748047  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 17  total_loss: 6.296597957611084  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 18  total_loss: 6.288796424865723  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 19  total_loss: 6.282958984375  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 20  total_loss: 6.278384208679199  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 21  total_loss: 6.274576663970947  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 22  total_loss: 6.271020889282227  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 23  total_loss: 6.267298221588135  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 24  total_loss: 6.263713359832764  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 25  total_loss: 6.260492324829102  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 26  total_loss: 6.256971836090088  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 27  total_loss: 6.253921031951904  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 28  total_loss: 6.250701427459717  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 29  total_loss: 6.247805595397949  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 30  total_loss: 6.244668960571289  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 31  total_loss: 6.2414937019348145  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 32  total_loss: 6.23832893371582  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 33  total_loss: 6.235764503479004  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 34  total_loss: 6.232846260070801  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 35  total_loss: 6.230363845825195  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 36  total_loss: 6.227718830108643  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 37  total_loss: 6.225342750549316  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 38  total_loss: 6.222956657409668  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 39  total_loss: 6.220591068267822  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 40  total_loss: 6.218272686004639  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 41  total_loss: 6.215931415557861  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 42  total_loss: 6.213857650756836  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 43  total_loss: 6.2116923332214355  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 44  total_loss: 6.209745407104492  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 45  total_loss: 6.207795143127441  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 46  total_loss: 6.205683708190918  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 47  total_loss: 6.204123497009277  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 48  total_loss: 6.2022318840026855  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 49  total_loss: 6.200494766235352  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 50  total_loss: 6.198702812194824  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 51  total_loss: 6.197098731994629  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 52  total_loss: 6.195471286773682  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 53  total_loss: 6.193899631500244  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 54  total_loss: 6.192450046539307  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 55  total_loss: 6.1910014152526855  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 56  total_loss: 6.1895904541015625  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 57  total_loss: 6.188258171081543  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 58  total_loss: 6.186947822570801  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 59  total_loss: 6.1855316162109375  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 60  total_loss: 6.184150695800781  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 61  total_loss: 6.183098316192627  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 62  total_loss: 6.18187141418457  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 63  total_loss: 6.180656909942627  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 64  total_loss: 6.179516792297363  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 65  total_loss: 6.178383827209473  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 66  total_loss: 6.1771721839904785  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 67  total_loss: 6.176121711730957  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 68  total_loss: 6.175114154815674  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 69  total_loss: 6.174079895019531  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 70  total_loss: 6.173038959503174  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 71  total_loss: 6.172136306762695  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 72  total_loss: 6.171115875244141  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 73  total_loss: 6.1702094078063965  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 74  total_loss: 6.169075965881348  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 75  total_loss: 6.168234825134277  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 76  total_loss: 6.167294502258301  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 77  total_loss: 6.166388988494873  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 78  total_loss: 6.165524005889893  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 79  total_loss: 6.1647114753723145  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 80  total_loss: 6.1639299392700195  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 81  total_loss: 6.163140296936035  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 82  total_loss: 6.162234783172607  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 83  total_loss: 6.161483287811279  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 84  total_loss: 6.160665512084961  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 85  total_loss: 6.159755229949951  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 86  total_loss: 6.159144401550293  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 87  total_loss: 6.158346176147461  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 88  total_loss: 6.157586097717285  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 89  total_loss: 6.156886100769043  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 90  total_loss: 6.156194686889648  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 91  total_loss: 6.155508995056152  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 92  total_loss: 6.154839515686035  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 93  total_loss: 6.154053688049316  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 94  total_loss: 6.153312683105469  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 95  total_loss: 6.152758598327637  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 96  total_loss: 6.15189266204834  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 97  total_loss: 6.151280879974365  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 98  total_loss: 6.1507649421691895  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 99  total_loss: 6.150046348571777  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 100  total_loss: 6.1494526863098145  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 101  total_loss: 6.14880895614624  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 102  total_loss: 6.148108959197998  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 103  total_loss: 6.147572994232178  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 104  total_loss: 6.146961212158203  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 105  total_loss: 6.146487236022949  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 106  total_loss: 6.145779609680176  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 107  total_loss: 6.145267486572266  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 108  total_loss: 6.144631862640381  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 109  total_loss: 6.14395809173584  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 110  total_loss: 6.143497467041016  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 111  total_loss: 6.142876625061035  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 112  total_loss: 6.1423234939575195  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 113  total_loss: 6.141811370849609  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 114  total_loss: 6.141293525695801  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 115  total_loss: 6.140791416168213  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 116  total_loss: 6.140213489532471  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 117  total_loss: 6.139741897583008  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 118  total_loss: 6.139143466949463  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 119  total_loss: 6.1385111808776855  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 120  total_loss: 6.138157844543457  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 121  total_loss: 6.137603759765625  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 122  total_loss: 6.137113094329834  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 123  total_loss: 6.136700630187988  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 124  total_loss: 6.13622522354126  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 125  total_loss: 6.135624885559082  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 126  total_loss: 6.135144233703613  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 127  total_loss: 6.134602069854736  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 128  total_loss: 6.134105682373047  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 129  total_loss: 6.133796215057373  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 130  total_loss: 6.133246421813965  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 131  total_loss: 6.132847785949707  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 132  total_loss: 6.132345199584961  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 133  total_loss: 6.132004261016846  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 134  total_loss: 6.1314496994018555  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 135  total_loss: 6.131052494049072  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 136  total_loss: 6.1305437088012695  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 137  total_loss: 6.130178451538086  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 138  total_loss: 6.129761219024658  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 139  total_loss: 6.12935209274292  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 140  total_loss: 6.128849506378174  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 141  total_loss: 6.128348350524902  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 142  total_loss: 6.12800931930542  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 143  total_loss: 6.127451419830322  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 144  total_loss: 6.127304553985596  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 145  total_loss: 6.126834869384766  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 146  total_loss: 6.12637186050415  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 147  total_loss: 6.126030445098877  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 148  total_loss: 6.12564754486084  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 149  total_loss: 6.125260353088379  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 150  total_loss: 6.1248087882995605  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 151  total_loss: 6.124475479125977  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 152  total_loss: 6.12399959564209  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 153  total_loss: 6.123694896697998  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 154  total_loss: 6.1233415603637695  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 155  total_loss: 6.123021125793457  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 156  total_loss: 6.122557640075684  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 157  total_loss: 6.122211933135986  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 158  total_loss: 6.121865749359131  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 159  total_loss: 6.1215620040893555  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 160  total_loss: 6.121219158172607  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 161  total_loss: 6.120882034301758  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 162  total_loss: 6.120546340942383  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 163  total_loss: 6.120126724243164  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 164  total_loss: 6.119907379150391  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 165  total_loss: 6.11955451965332  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 166  total_loss: 6.119286060333252  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 167  total_loss: 6.1189165115356445  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 168  total_loss: 6.1185455322265625  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 169  total_loss: 6.1183085441589355  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 170  total_loss: 6.117937088012695  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 171  total_loss: 6.117600440979004  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 172  total_loss: 6.1173858642578125  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 173  total_loss: 6.117007255554199  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 174  total_loss: 6.116775989532471  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 175  total_loss: 6.1165080070495605  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 176  total_loss: 6.116242408752441  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 177  total_loss: 6.115755558013916  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 178  total_loss: 6.115593910217285  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 179  total_loss: 6.115138053894043  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 180  total_loss: 6.114988803863525  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 181  total_loss: 6.11469841003418  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 182  total_loss: 6.114444732666016  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 183  total_loss: 6.114067554473877  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 184  total_loss: 6.113813877105713  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 185  total_loss: 6.113579273223877  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 186  total_loss: 6.1133246421813965  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 187  total_loss: 6.11305570602417  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 188  total_loss: 6.112705707550049  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 189  total_loss: 6.112565994262695  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 190  total_loss: 6.112259864807129  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 191  total_loss: 6.111897945404053  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 192  total_loss: 6.111767292022705  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 193  total_loss: 6.111497402191162  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 194  total_loss: 6.1112260818481445  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 195  total_loss: 6.110947608947754  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 196  total_loss: 6.110625743865967  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 197  total_loss: 6.110482692718506  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 198  total_loss: 6.11025333404541  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 199  total_loss: 6.10986328125  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 200  total_loss: 6.109773635864258  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 201  total_loss: 6.1093926429748535  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 202  total_loss: 6.109212398529053  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 203  total_loss: 6.1089863777160645  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 204  total_loss: 6.1087493896484375  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 205  total_loss: 6.108449935913086  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 206  total_loss: 6.108271598815918  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 207  total_loss: 6.108080863952637  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 208  total_loss: 6.10768985748291  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 209  total_loss: 6.107525825500488  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 210  total_loss: 6.107395172119141  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 211  total_loss: 6.107165813446045  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 212  total_loss: 6.106874465942383  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 213  total_loss: 6.106614112854004  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 214  total_loss: 6.106339454650879  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 215  total_loss: 6.10619592666626  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 216  total_loss: 6.105963230133057  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 217  total_loss: 6.105717658996582  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 218  total_loss: 6.105496406555176  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 219  total_loss: 6.105228900909424  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 220  total_loss: 6.105048656463623  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 221  total_loss: 6.1048455238342285  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 222  total_loss: 6.104555130004883  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 223  total_loss: 6.104323387145996  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 224  total_loss: 6.104196071624756  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 225  total_loss: 6.104019641876221  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 226  total_loss: 6.103774070739746  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 227  total_loss: 6.103600025177002  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 228  total_loss: 6.103278636932373  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 229  total_loss: 6.103200912475586  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 230  total_loss: 6.102907657623291  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 231  total_loss: 6.102693557739258  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 232  total_loss: 6.102466583251953  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 233  total_loss: 6.102200984954834  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 234  total_loss: 6.102114200592041  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 235  total_loss: 6.101813316345215  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 236  total_loss: 6.101589202880859  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 237  total_loss: 6.10141134262085  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 238  total_loss: 6.101222038269043  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 239  total_loss: 6.101068496704102  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 240  total_loss: 6.100881576538086  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 241  total_loss: 6.530223846435547  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 242  total_loss: 6.528948783874512  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 243  total_loss: 6.475644111633301  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 244  total_loss: 6.1768999099731445  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 245  total_loss: 6.245621204376221  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 246  total_loss: 6.246981620788574  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 247  total_loss: 6.245728969573975  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 248  total_loss: 6.217426300048828  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 249  total_loss: 6.1862993240356445  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 250  total_loss: 6.184624195098877  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 251  total_loss: 6.180294036865234  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 252  total_loss: 6.165652751922607  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 253  total_loss: 6.160549163818359  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 254  total_loss: 6.153700351715088  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 255  total_loss: 6.148882865905762  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 256  total_loss: 6.143824100494385  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 257  total_loss: 6.138879776000977  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 258  total_loss: 6.135687351226807  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 259  total_loss: 6.132867336273193  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 260  total_loss: 6.12838077545166  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 261  total_loss: 6.1253581047058105  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 262  total_loss: 6.122868537902832  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 263  total_loss: 6.1207404136657715  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 264  total_loss: 6.118879795074463  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 265  total_loss: 6.117076396942139  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 266  total_loss: 6.11546516418457  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 267  total_loss: 6.114304542541504  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 268  total_loss: 6.1129937171936035  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 269  total_loss: 6.111208438873291  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 270  total_loss: 6.109522342681885  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 271  total_loss: 6.108397960662842  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 272  total_loss: 6.10757303237915  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 273  total_loss: 6.106812477111816  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 274  total_loss: 6.106005668640137  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 275  total_loss: 6.105085372924805  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 276  total_loss: 6.104242324829102  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 277  total_loss: 6.103139400482178  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 278  total_loss: 6.1024885177612305  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 279  total_loss: 6.101728439331055  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 280  total_loss: 6.101019382476807  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 281  total_loss: 6.100244522094727  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 282  total_loss: 6.099758148193359  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 283  total_loss: 6.099147796630859  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 284  total_loss: 6.098690509796143  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 285  total_loss: 6.098409652709961  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 286  total_loss: 6.097978115081787  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 287  total_loss: 6.097784042358398  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 288  total_loss: 6.097394943237305  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 289  total_loss: 6.097103595733643  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 290  total_loss: 6.096760272979736  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 291  total_loss: 6.096635341644287  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 292  total_loss: 6.096288681030273  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 293  total_loss: 6.096086025238037  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 294  total_loss: 6.0960001945495605  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 295  total_loss: 6.09574031829834  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 296  total_loss: 6.095451831817627  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 297  total_loss: 6.095298767089844  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 298  total_loss: 6.0950541496276855  alpha: 10  beta: 0.3  gama: 0.7
# epoch: 299  total_loss: 6.09496545791626  alpha: 10  beta: 0.3  gama: 0.7
# === load ===
# embedding generated, go clustering
# calculate metric ARI
# ARI: 0.06070437389827368
# NMI: 0.1506623573664101
# complete!

# %%
from matplotlib import pyplot as plt

color=['domain','ground_truth']
sc.pp.neighbors(adata, use_rep='z', metric='cosine')
sc.tl.umap(adata)
for i in color:
    sc.pl.umap(adata, color=i, show=False)
    plt.savefig('./results/'+args.dataset+'/'+args.slice+'/'+i+'_umap.png')
    plt.show()

# %%
adata=sc.read_h5ad('./results/'+args.dataset+'/'+args.slice+'/STAMGC.h5ad')
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 20674 × 1933
#     obs: 'barcode', 'x', 'y', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_MT', 'log1p_total_counts_MT', 'pct_counts_MT', 'n_counts', 'leiden', 'cluster', 'ground_truth', 'pseudo_labels', 'domain'
#     var: 'MT', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'dispersions', 'dispersions_norm', 'n_counts', 'mean', 'std'
#     uns: 'ari', 'cluster_colors', 'domain_colors', 'ground_truth_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'moranI', 'neighbors', 'nmi', 'pca', 'smooth_r', 'spatial_neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'deconvolution_results', 'emb_pca', 'gene_feat', 'graph_neigh', 'graph_neigh_coor', 'h', 'mlp', 'negative_mask', 'smooth_gene', 'spatial', 'z'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances', 'spatial_connectivities', 'spatial_distances'

# %%
import pandas as pd
from matplotlib import pyplot as plt
pl = ['#9467bd', '#bcbd22', '#aec7e8', '#ff7f0e']
title=['CA1','CA3','DG','CA']
adata.obs['domain']=adata.obs['domain'].astype('str')
clusters = ['14','10','7','10&14']
print(clusters)
# 创建保存目录
output_dir = f'./results/{args.dataset}/{args.slice}/clusters'
os.makedirs(output_dir, exist_ok=True)
n_type = 4
zeros = np.zeros([adata.n_obs, n_type])
matrix_clusters = pd.DataFrame(zeros, index=adata.obs_names, columns=clusters)
for cell in list(adata.obs_names):
    cluster = adata.obs.loc[cell, 'domain']
    matrix_clusters.loc[cell, str(cluster)] = cluster
    if cluster in ['10','14']:
        matrix_clusters.loc[cell, '10&14'] = '10&14'
adata.obs[matrix_clusters.columns] = matrix_clusters.astype(str)
# 为每个聚类创建单独的可视化
for j,cluster in enumerate(clusters):
    print(cluster)
    sc.pl.embedding(adata, basis="spatial", color=cluster, s=20,title=title[j], palette=['gray', pl[j]],show=False)
    plt.savefig(output_dir +'/'+ title[j] + '.png',bbox_inches='tight', dpi=600)
    plt.show()
# Out:
# ['14', '10', '7', '10&14']
# 14
# 10
# 7
# 10&14

# %%
data=sc.read_h5ad(slice_path+'.h5ad')
sc.pp.normalize_total(data, target_sum=1e4)
sc.pp.log1p(data)
sc.pp.scale(data, zero_center=False, max_value=10)
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
from package.utils import plot_spatial_gene_expression
# adata.obs['domain']=adata.obs['domain'].astype('str')
marker_genes=['Hpca','Wfs1','Chgb','C1ql2','Mbp']
output_dir = f'./results/{args.dataset}/{args.slice}/genes'
os.makedirs(output_dir, exist_ok=True)
for i in marker_genes:
    plot_spatial_gene_expression(data,i,spot_size=3,save_path=f'./results/{args.dataset}/{args.slice}/genes/{i}_spatial.png',platform='Slide_seqV2')
# Out:
# 绘制基因 'Hpca' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Neocortex/Mouse_Neocortex_data/genes/Hpca_spatial.png
# 绘制基因 'Wfs1' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Neocortex/Mouse_Neocortex_data/genes/Wfs1_spatial.png
# 绘制基因 'Chgb' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Neocortex/Mouse_Neocortex_data/genes/Chgb_spatial.png
# 绘制基因 'C1ql2' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Neocortex/Mouse_Neocortex_data/genes/C1ql2_spatial.png
# 绘制基因 'Mbp' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Neocortex/Mouse_Neocortex_data/genes/Mbp_spatial.png
