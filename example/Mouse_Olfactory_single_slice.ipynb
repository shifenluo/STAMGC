# %% [markdown]
# Mouse_Olfactory_single_slice

# %%
import random
import numpy as np
import scanpy as sc
import torch
import argparse
import yaml
from yaml import SafeLoader
from package.data_processing import LoadAdata
from package.model import STAMGC
import warnings


warnings.filterwarnings('ignore')
import os
os.chdir('/root/autodl-tmp/zhangzhuoyue/code/第一个工作3.0')

# %%
file_fold='/root/autodl-tmp/zhangzhuoyue/data'

args = argparse.Namespace(
    dataset='Mouse_Olfactory_Bulb',
    slice='Stereo_seq',
    batch_size=1,
    platform='Stereo_seq',
    parameter='Stereo_seq',
    spot_size=20,
    config='./train_config.yaml',
    label=False,
)
config = yaml.load(open(args.config), Loader=SafeLoader)[str(args.parameter)]

slice_path = os.path.join(file_fold, args.dataset, args.slice)

torch.manual_seed(config['seed'])
np.random.seed(config['seed'])
if torch.cuda.is_available():
    torch.cuda.manual_seed(config['seed'])
    torch.cuda.manual_seed_all(config['seed'])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
random.seed(12345)
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8' 
torch.use_deterministic_algorithms(True)

# %%
from package.utils import create_dir
save_path='./results/'+args.dataset+'/'+args.slice
create_dir(save_path)
# Out:
# './results/Mouse_Olfactory_Bulb/Stereo_seq'

# %%
# adata = LoadAdata(path=slice_path,dataset=args.dataset,slice=args.slice,config=config,args=args).run()
# print(adata)

# %%
adata=sc.read_h5ad('./results/'+args.dataset+'/'+args.slice+'/data_processing.h5ad')
# print(adata)

# %%
# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = (10, 5)
adata=STAMGC(adata,config,args).run()
# Out:
# === Generate pseudo labels! ===
# === train ===
# epoch: 0  total_loss: 8.105999946594238  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 1  total_loss: 8.010948181152344  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 2  total_loss: 7.936904430389404  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 3  total_loss: 7.8491034507751465  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 4  total_loss: 7.768799304962158  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 5  total_loss: 7.7065043449401855  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 6  total_loss: 7.647381782531738  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 7  total_loss: 7.604788303375244  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 8  total_loss: 7.559598922729492  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 9  total_loss: 7.514858245849609  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 10  total_loss: 7.497939109802246  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 11  total_loss: 7.472287178039551  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 12  total_loss: 7.45829963684082  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 13  total_loss: 7.444230079650879  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 14  total_loss: 7.433082103729248  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 15  total_loss: 7.424391269683838  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 16  total_loss: 7.418360710144043  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 17  total_loss: 7.413015365600586  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 18  total_loss: 7.408634662628174  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 19  total_loss: 7.404696464538574  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 20  total_loss: 7.4012556076049805  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 21  total_loss: 7.398038387298584  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 22  total_loss: 7.395063400268555  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 23  total_loss: 7.3922014236450195  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 24  total_loss: 7.389301300048828  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 25  total_loss: 7.3863725662231445  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 26  total_loss: 7.383759498596191  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 27  total_loss: 7.381149768829346  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 28  total_loss: 7.378653049468994  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 29  total_loss: 7.376126289367676  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 30  total_loss: 7.373610973358154  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 31  total_loss: 7.3710737228393555  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 32  total_loss: 7.368527412414551  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 33  total_loss: 7.36582088470459  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 34  total_loss: 7.363106727600098  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 35  total_loss: 7.360150337219238  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 36  total_loss: 7.356986045837402  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 37  total_loss: 7.353898525238037  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 38  total_loss: 7.350430965423584  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 39  total_loss: 7.346682071685791  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 40  total_loss: 7.3431854248046875  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 41  total_loss: 7.339605331420898  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 42  total_loss: 7.336596965789795  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 43  total_loss: 7.333567142486572  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 44  total_loss: 7.330703258514404  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 45  total_loss: 7.328054904937744  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 46  total_loss: 7.32549524307251  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 47  total_loss: 7.323139190673828  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 48  total_loss: 7.321022987365723  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 49  total_loss: 7.318783760070801  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 50  total_loss: 7.316751480102539  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 51  total_loss: 7.314733028411865  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 52  total_loss: 7.312568187713623  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 53  total_loss: 7.310540676116943  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 54  total_loss: 7.308470726013184  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 55  total_loss: 7.306727886199951  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 56  total_loss: 7.30493688583374  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 57  total_loss: 7.303138256072998  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 58  total_loss: 7.301539897918701  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 59  total_loss: 7.300018310546875  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 60  total_loss: 7.298306941986084  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 61  total_loss: 7.297177314758301  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 62  total_loss: 7.295715808868408  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 63  total_loss: 7.294429779052734  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 64  total_loss: 7.293188095092773  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 65  total_loss: 7.2920355796813965  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 66  total_loss: 7.290920734405518  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 67  total_loss: 7.2899088859558105  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 68  total_loss: 7.2889485359191895  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 69  total_loss: 7.288074970245361  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 70  total_loss: 7.287269115447998  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 71  total_loss: 7.28648042678833  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 72  total_loss: 7.285694122314453  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 73  total_loss: 7.284947395324707  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 74  total_loss: 7.284284591674805  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 75  total_loss: 7.283571243286133  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 76  total_loss: 7.282820701599121  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 77  total_loss: 7.282277584075928  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 78  total_loss: 7.281705856323242  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 79  total_loss: 7.281083106994629  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 80  total_loss: 7.280496120452881  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 81  total_loss: 7.2798895835876465  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 82  total_loss: 7.2793498039245605  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 83  total_loss: 7.278835296630859  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 84  total_loss: 7.278263092041016  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 85  total_loss: 7.277807235717773  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 86  total_loss: 7.277318477630615  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 87  total_loss: 7.276899337768555  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 88  total_loss: 7.276352405548096  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 89  total_loss: 7.275900363922119  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 90  total_loss: 7.275463581085205  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 91  total_loss: 7.275058746337891  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 92  total_loss: 7.274571895599365  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 93  total_loss: 7.2741594314575195  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 94  total_loss: 7.273795127868652  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 95  total_loss: 7.273324012756348  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 96  total_loss: 7.272911548614502  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 97  total_loss: 7.272472381591797  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 98  total_loss: 7.27215576171875  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 99  total_loss: 7.271828651428223  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 100  total_loss: 7.271504878997803  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 101  total_loss: 7.270992755889893  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 102  total_loss: 7.270691871643066  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 103  total_loss: 7.270384788513184  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 104  total_loss: 7.269959926605225  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 105  total_loss: 7.269693851470947  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 106  total_loss: 7.26943826675415  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 107  total_loss: 7.269074440002441  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 108  total_loss: 7.268674373626709  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 109  total_loss: 7.268379211425781  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 110  total_loss: 7.268081188201904  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 111  total_loss: 7.267831802368164  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 112  total_loss: 7.26740026473999  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 113  total_loss: 7.267311096191406  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 114  total_loss: 7.2668776512146  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 115  total_loss: 7.2666730880737305  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 116  total_loss: 7.266427040100098  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 117  total_loss: 7.265988349914551  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 118  total_loss: 7.265817165374756  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 119  total_loss: 7.265449523925781  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 120  total_loss: 7.265222549438477  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 121  total_loss: 7.264974117279053  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 122  total_loss: 7.264692783355713  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 123  total_loss: 7.264383316040039  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 124  total_loss: 7.264161586761475  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 125  total_loss: 7.263980865478516  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 126  total_loss: 7.263612747192383  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 127  total_loss: 7.2634053230285645  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 128  total_loss: 7.263130187988281  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 129  total_loss: 7.262846946716309  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 130  total_loss: 7.262597560882568  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 131  total_loss: 7.2624616622924805  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 132  total_loss: 7.262176513671875  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 133  total_loss: 7.261939525604248  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 134  total_loss: 7.261659622192383  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 135  total_loss: 7.261373519897461  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 136  total_loss: 7.2611260414123535  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 137  total_loss: 7.260919094085693  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 138  total_loss: 7.260729789733887  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 139  total_loss: 7.260560989379883  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 140  total_loss: 7.260292053222656  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 141  total_loss: 7.259973049163818  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 142  total_loss: 7.259838581085205  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 143  total_loss: 7.2596354484558105  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 144  total_loss: 7.259404182434082  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 145  total_loss: 7.2591071128845215  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 146  total_loss: 7.25894832611084  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 147  total_loss: 7.258815288543701  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 148  total_loss: 7.258550643920898  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 149  total_loss: 7.258265972137451  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 150  total_loss: 7.258090019226074  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 151  total_loss: 7.257795810699463  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 152  total_loss: 7.257646560668945  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 153  total_loss: 7.257388114929199  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 154  total_loss: 7.257266044616699  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 155  total_loss: 7.256989002227783  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 156  total_loss: 7.256838798522949  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 157  total_loss: 7.2566447257995605  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 158  total_loss: 7.25639009475708  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 159  total_loss: 7.25615930557251  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 160  total_loss: 7.25598669052124  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 161  total_loss: 7.255735874176025  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 162  total_loss: 7.25559139251709  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 163  total_loss: 7.255380153656006  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 164  total_loss: 7.255255222320557  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 165  total_loss: 7.254936695098877  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 166  total_loss: 7.254820346832275  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 167  total_loss: 7.254575729370117  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 168  total_loss: 7.254472732543945  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 169  total_loss: 7.25430965423584  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 170  total_loss: 7.254058361053467  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 171  total_loss: 7.25390625  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 172  total_loss: 7.253751754760742  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 173  total_loss: 7.253451347351074  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 174  total_loss: 7.253302574157715  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 175  total_loss: 7.253116607666016  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 176  total_loss: 7.2530598640441895  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 177  total_loss: 7.2528533935546875  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 178  total_loss: 7.252686500549316  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 179  total_loss: 7.2525482177734375  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 180  total_loss: 7.252242088317871  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 181  total_loss: 7.252080917358398  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 182  total_loss: 7.251989364624023  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 183  total_loss: 7.251750946044922  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 184  total_loss: 7.251551628112793  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 185  total_loss: 7.251558780670166  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 186  total_loss: 7.251351356506348  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 187  total_loss: 7.251127243041992  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 188  total_loss: 7.251009464263916  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 189  total_loss: 7.250891208648682  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 190  total_loss: 7.25071907043457  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 191  total_loss: 7.250542640686035  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 192  total_loss: 7.250395774841309  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 193  total_loss: 7.250304698944092  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 194  total_loss: 7.250141143798828  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 195  total_loss: 7.2500152587890625  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 196  total_loss: 7.24979305267334  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 197  total_loss: 7.249701976776123  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 198  total_loss: 7.249601364135742  alpha: 6  beta: 0.1  gama: 0.9
# epoch: 199  total_loss: 7.249569416046143  alpha: 6  beta: 0.1  gama: 0.9
# === load ===
# embedding generated, go clustering
# calculate SC and DB
# SC: 0.28125042
# DB: 1.2970630210569427
# complete!

# %%
adata=sc.read_h5ad('./results/Mouse_Olfactory_Bulb/Stereo_seq/STAMGC.h5ad')
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 19527 × 3000
#     obs: 'pseudo_labels', 'domain'
#     var: 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'db', 'domain_colors', 'hvg', 'log1p', 'sc', 'smooth_r'
#     obsm: 'emb_pca', 'gene_feat', 'graph_neigh', 'graph_neigh_coor', 'h', 'mlp', 'negative_mask', 'smooth_gene', 'spatial', 'z'

# %%
from matplotlib import pyplot as plt

color=['domain']
sc.pp.neighbors(adata, use_rep='z', metric='cosine')
sc.tl.umap(adata)
# plt.rcParams['figure.figsize'] = (6, 5)
for i in color:
    sc.pl.umap(adata, color=i, show=False)
    plt.savefig('./results/'+args.dataset+'/'+args.slice+'/'+i+'_umap.png', bbox_inches='tight',dpi=600)
    plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
pl = ['#1f77b4ff', '#ff7f0eff', '#2ca02cff', '#d62728ff', '#9467bdff', '#8c564bff','#e377c2ff']
title=['GCL','GL','ONL','EPL','IPL','MCL','RMS']
adata.obs['domain']=adata.obs['domain'].astype('str')
clusters = adata.obs['domain'].unique()
print(clusters)
# 创建保存目录
output_dir = './results/Mouse_Olfactory_Bulb/Stereo_seq/clusters'
os.makedirs(output_dir, exist_ok=True)
n_type = config['num_clusters']
zeros = np.zeros([adata.n_obs, n_type])
matrix_clusters = pd.DataFrame(zeros, index=adata.obs_names, columns=clusters)
for cell in list(adata.obs_names):
    cluster = adata.obs.loc[cell, 'domain']
    matrix_clusters.loc[cell, str(cluster)] = cluster
adata.obs[matrix_clusters.columns] = matrix_clusters.astype(str)
# 为每个聚类创建单独的可视化
for j,cluster in enumerate(sorted(clusters)):
    print(cluster)
    sc.pl.embedding(adata, basis="spatial", color=cluster, s=10,title=title[j], palette=['gray', pl[j]],show=False)
    plt.savefig(output_dir +'/'+ title[j] + '.png',bbox_inches='tight', dpi=600)
    plt.show()
# Out:
# ['3' '4' '2' '6' '5' '1' '7']
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
from package.utils import plot_spatial_gene_expression

data=sc.read_h5ad(file_fold+'/'+args.dataset+'/'+args.slice+'/raw.h5ad')
print(data)
sc.pp.normalize_total(data, target_sum=1e4)
sc.pp.log1p(data)
sc.pp.scale(data, zero_center=False, max_value=10)
data.obsm['spatial'][:,1]=-1*data.obsm['spatial'][:,1]
marker_genes=['Mbp','Nrgn','Pcp4','Gabra1','Slc6a11','Cck','Apod']
for i in marker_genes:
    plot_spatial_gene_expression(data,i,spot_size=0.5,save_path=f'./results/{args.dataset}/{args.slice}/genes/{i}_spatial.png')
# Out:
# AnnData object with n_obs × n_vars = 19527 × 27106
#     obsm: 'spatial'
# 绘制基因 'Mbp' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Olfactory_Bulb/Stereo_seq/genes/Mbp_spatial.png
# 绘制基因 'Nrgn' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Olfactory_Bulb/Stereo_seq/genes/Nrgn_spatial.png
# 绘制基因 'Pcp4' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Olfactory_Bulb/Stereo_seq/genes/Pcp4_spatial.png
# 绘制基因 'Gabra1' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Olfactory_Bulb/Stereo_seq/genes/Gabra1_spatial.png
# 绘制基因 'Slc6a11' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Olfactory_Bulb/Stereo_seq/genes/Slc6a11_spatial.png
# 绘制基因 'Cck' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Olfactory_Bulb/Stereo_seq/genes/Cck_spatial.png
# 绘制基因 'Apod' 的空间表达分布...
# 图像已保存到: ./results/Mouse_Olfactory_Bulb/Stereo_seq/genes/Apod_spatial.png

# %%
# g=1220
# adata.obs['gene']=adata.obsm['gene_feat'][:,g]
# adata.obs['gaussian_smooth']=adata.obsm['smooth_gene'][:,g]
# print(adata.var_names[g])
# sc.pl.embedding(adata, basis='spatial', size=20,color=['gene','gaussian_smooth'], show=True)

# %%
# from package.utils import knn_adj_matrix
# from scipy.spatial.distance import cdist
# import pandas as pd
# coor = pd.DataFrame(adata.obsm['spatial'])
# coor_k_interaction = knn_adj_matrix(coor,4,metric='euclidean')
# print('1')
# 
# smooth_gene = pd.DataFrame(adata.obsm['smooth_gene'])
# smooth_gene_cosine=cdist(smooth_gene,smooth_gene,'cosine')
# print('2')
# for i in range(1):
#     smooth_gene_cosine_matrix=coor_k_interaction*smooth_gene_cosine
#     del_col_idx = smooth_gene_cosine_matrix.argmax(axis=1)  # 每行第一个最大值的列索引
#     coor_k_interaction[np.arange(len(del_col_idx)), del_col_idx] = 0
# print('3')
# coor_adj = coor_k_interaction + coor_k_interaction.T
# coor_adj = np.where(coor_adj > 1, 1, coor_adj)
# coor_adj=coor_adj-np.eye(coor_adj.shape[0])

# %%
# import networkx as nx
# import matplotlib.pyplot as plt
# 
# A = adata.obsm['graph_neigh']# 邻接矩阵
# pos = adata.obsm['spatial']# 每行对应节点的真实坐标
# 
# # 2. 建图
# G = nx.from_numpy_array(A)             # 无向图；有向加 create_using=nx.DiGraph
# 
# # 3. 把坐标转成 NetworkX 要的 dict 格式
# pos_dict = {i: pos[i] for i in range(len(pos))}
# 
# # 4. 画图
# plt.figure(figsize=(8,8))
# nx.draw(G, pos_dict,
#         with_labels=False,
#         node_color='orange',
#         edgecolors='black',
#         node_size=1,
#         font_weight='bold')
# plt.axis('equal')                      # 保持 x/y 比例一致
# plt.show()
